# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in learning_rates:
    for reg in regularization_strengths:
        svm = LinearSVM()
        loss_hist = svm.train(X_train_feats, y_train, learning_rate=lr, reg=reg, num_iters=4000, verbose=False)
        
        y_train_pred = svm.predict(X_train_feats)
        training_accuracy = np.mean(y_train == y_train_pred)
        
        y_val_pred = svm.predict(X_val_feats)
        validation_accuracy = np.mean(y_val == y_val_pred)
        
        if validation_accuracy > best_val:
            best_val = validation_accuracy
            best_svm = svm
            
        results[(lr, reg)] = (training_accuracy, validation_accuracy)
        print('training accuracy: %f validation accuracy: %f' % (training_accuracy, validation_accuracy))

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# training accuracy: 0.108449 validation accuracy: 0.088000
# training accuracy: 0.119898 validation accuracy: 0.117000
# training accuracy: 0.415163 validation accuracy: 0.416000
# training accuracy: 0.123204 validation accuracy: 0.144000
# training accuracy: 0.414612 validation accuracy: 0.411000
# training accuracy: 0.417878 validation accuracy: 0.414000
# training accuracy: 0.412265 validation accuracy: 0.408000
# training accuracy: 0.409694 validation accuracy: 0.405000
# training accuracy: 0.320653 validation accuracy: 0.315000
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.108449 val accuracy: 0.088000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.119898 val accuracy: 0.117000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.415163 val accuracy: 0.416000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.123204 val accuracy: 0.144000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.414612 val accuracy: 0.411000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.417878 val accuracy: 0.414000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.412265 val accuracy: 0.408000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.409694 val accuracy: 0.405000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.320653 val accuracy: 0.315000
# best validation accuracy achieved during cross-validation: 0.416000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.422

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$ Planes have blue, or light green background. Deers have green background. So, the miscalculation is because of colors

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.

learning_rates = np.arange(1, 10, 1)*1e-1
regularization_strengths = np.arange(1, 10, 1)*1e-5

for lr in learning_rates:
    for reg in regularization_strengths:
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)
        loss_hist = net.train(X_train_feats, y_train, X_val_feats, y_val, num_iters=4000, batch_size=200,
                  learning_rate=lr, learning_rate_decay=0.95, reg=reg, verbose=False)
        
        y_train_pred = net.predict(X_train_feats)
        training_accuracy = np.mean(y_train == y_train_pred)

        y_val_pred = net.predict(X_val_feats)
        validation_accuracy = np.mean(y_val == y_val_pred)
        

        if validation_accuracy > best_val:
            best_val = validation_accuracy
            best_net = net

        results[(lr, reg)] = (training_accuracy, validation_accuracy)
        print('lr %e reg %e training accuracy: %f validation accuracy: %f' % 
              (lr, reg,  training_accuracy, validation_accuracy))
    print (' ')
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f, val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# lr 1.000000e-01 reg 1.000000e-05 training accuracy: 0.613020 validation accuracy: 0.580000
# lr 1.000000e-01 reg 2.000000e-05 training accuracy: 0.614673 validation accuracy: 0.565000
# lr 1.000000e-01 reg 3.000000e-05 training accuracy: 0.612367 validation accuracy: 0.576000
# lr 1.000000e-01 reg 4.000000e-05 training accuracy: 0.613857 validation accuracy: 0.570000
# lr 1.000000e-01 reg 5.000000e-05 training accuracy: 0.612265 validation accuracy: 0.579000
# lr 1.000000e-01 reg 6.000000e-05 training accuracy: 0.612878 validation accuracy: 0.572000
# lr 1.000000e-01 reg 7.000000e-05 training accuracy: 0.611959 validation accuracy: 0.571000
# lr 1.000000e-01 reg 8.000000e-05 training accuracy: 0.612571 validation accuracy: 0.572000
# lr 1.000000e-01 reg 9.000000e-05 training accuracy: 0.611347 validation accuracy: 0.575000
#
# lr 2.000000e-01 reg 1.000000e-05 training accuracy: 0.712041 validation accuracy: 0.588000
# lr 2.000000e-01 reg 2.000000e-05 training accuracy: 0.709061 validation accuracy: 0.600000
# lr 2.000000e-01 reg 3.000000e-05 training accuracy: 0.711367 validation accuracy: 0.608000
# lr 2.000000e-01 reg 4.000000e-05 training accuracy: 0.709612 validation accuracy: 0.597000
# lr 2.000000e-01 reg 5.000000e-05 training accuracy: 0.707551 validation accuracy: 0.590000
# lr 2.000000e-01 reg 6.000000e-05 training accuracy: 0.709020 validation accuracy: 0.599000
# lr 2.000000e-01 reg 7.000000e-05 training accuracy: 0.705367 validation accuracy: 0.595000
# lr 2.000000e-01 reg 8.000000e-05 training accuracy: 0.707204 validation accuracy: 0.592000
# lr 2.000000e-01 reg 9.000000e-05 training accuracy: 0.708306 validation accuracy: 0.584000
#
# lr 3.000000e-01 reg 1.000000e-05 training accuracy: 0.768306 validation accuracy: 0.579000
# lr 3.000000e-01 reg 2.000000e-05 training accuracy: 0.774143 validation accuracy: 0.604000
# lr 3.000000e-01 reg 3.000000e-05 training accuracy: 0.772041 validation accuracy: 0.605000
# lr 3.000000e-01 reg 4.000000e-05 training accuracy: 0.770510 validation accuracy: 0.597000
# lr 3.000000e-01 reg 5.000000e-05 training accuracy: 0.767898 validation accuracy: 0.585000
# lr 3.000000e-01 reg 6.000000e-05 training accuracy: 0.765469 validation accuracy: 0.603000
# lr 3.000000e-01 reg 7.000000e-05 training accuracy: 0.768837 validation accuracy: 0.606000
# lr 3.000000e-01 reg 8.000000e-05 training accuracy: 0.762959 validation accuracy: 0.611000
# lr 3.000000e-01 reg 9.000000e-05 training accuracy: 0.766265 validation accuracy: 0.583000
#
# lr 4.000000e-01 reg 1.000000e-05 training accuracy: 0.819347 validation accuracy: 0.587000
# lr 4.000000e-01 reg 2.000000e-05 training accuracy: 0.809041 validation accuracy: 0.574000
# lr 4.000000e-01 reg 3.000000e-05 training accuracy: 0.810918 validation accuracy: 0.593000
# lr 4.000000e-01 reg 4.000000e-05 training accuracy: 0.808286 validation accuracy: 0.593000
# lr 4.000000e-01 reg 5.000000e-05 training accuracy: 0.806612 validation accuracy: 0.580000
# lr 4.000000e-01 reg 6.000000e-05 training accuracy: 0.809776 validation accuracy: 0.592000
# lr 4.000000e-01 reg 7.000000e-05 training accuracy: 0.808184 validation accuracy: 0.577000
# lr 4.000000e-01 reg 8.000000e-05 training accuracy: 0.800653 validation accuracy: 0.594000
# lr 4.000000e-01 reg 9.000000e-05 training accuracy: 0.801347 validation accuracy: 0.616000
#
# lr 5.000000e-01 reg 1.000000e-05 training accuracy: 0.835633 validation accuracy: 0.587000
# lr 5.000000e-01 reg 2.000000e-05 training accuracy: 0.833776 validation accuracy: 0.568000
# lr 5.000000e-01 reg 3.000000e-05 training accuracy: 0.835020 validation accuracy: 0.572000
# lr 5.000000e-01 reg 4.000000e-05 training accuracy: 0.839959 validation accuracy: 0.596000
# lr 5.000000e-01 reg 5.000000e-05 training accuracy: 0.832041 validation accuracy: 0.585000
# lr 5.000000e-01 reg 6.000000e-05 training accuracy: 0.840041 validation accuracy: 0.585000
# lr 5.000000e-01 reg 7.000000e-05 training accuracy: 0.832265 validation accuracy: 0.574000
# lr 5.000000e-01 reg 8.000000e-05 training accuracy: 0.824082 validation accuracy: 0.575000
# lr 5.000000e-01 reg 9.000000e-05 training accuracy: 0.830816 validation accuracy: 0.582000
#
# lr 6.000000e-01 reg 1.000000e-05 training accuracy: 0.861959 validation accuracy: 0.579000
# lr 6.000000e-01 reg 2.000000e-05 training accuracy: 0.860388 validation accuracy: 0.563000
# lr 6.000000e-01 reg 3.000000e-05 training accuracy: 0.858633 validation accuracy: 0.584000
# lr 6.000000e-01 reg 4.000000e-05 training accuracy: 0.859857 validation accuracy: 0.574000
# lr 6.000000e-01 reg 5.000000e-05 training accuracy: 0.857408 validation accuracy: 0.584000
# lr 6.000000e-01 reg 6.000000e-05 training accuracy: 0.854510 validation accuracy: 0.586000
# lr 6.000000e-01 reg 7.000000e-05 training accuracy: 0.851633 validation accuracy: 0.586000
# lr 6.000000e-01 reg 8.000000e-05 training accuracy: 0.852551 validation accuracy: 0.594000
# lr 6.000000e-01 reg 9.000000e-05 training accuracy: 0.849959 validation accuracy: 0.581000
#
# lr 7.000000e-01 reg 1.000000e-05 training accuracy: 0.868347 validation accuracy: 0.572000
# lr 7.000000e-01 reg 2.000000e-05 training accuracy: 0.875327 validation accuracy: 0.589000
# lr 7.000000e-01 reg 3.000000e-05 training accuracy: 0.870490 validation accuracy: 0.577000
# lr 7.000000e-01 reg 4.000000e-05 training accuracy: 0.865551 validation accuracy: 0.574000
# lr 7.000000e-01 reg 5.000000e-05 training accuracy: 0.872306 validation accuracy: 0.582000
# lr 7.000000e-01 reg 6.000000e-05 training accuracy: 0.862184 validation accuracy: 0.579000
# lr 7.000000e-01 reg 7.000000e-05 training accuracy: 0.862469 validation accuracy: 0.563000
# lr 7.000000e-01 reg 8.000000e-05 training accuracy: 0.865469 validation accuracy: 0.567000
# lr 7.000000e-01 reg 9.000000e-05 training accuracy: 0.864531 validation accuracy: 0.574000
#
# lr 8.000000e-01 reg 1.000000e-05 training accuracy: 0.887612 validation accuracy: 0.581000
# lr 8.000000e-01 reg 2.000000e-05 training accuracy: 0.879633 validation accuracy: 0.576000
# lr 8.000000e-01 reg 3.000000e-05 training accuracy: 0.878714 validation accuracy: 0.549000
# lr 8.000000e-01 reg 4.000000e-05 training accuracy: 0.884939 validation accuracy: 0.561000
# lr 8.000000e-01 reg 5.000000e-05 training accuracy: 0.882347 validation accuracy: 0.577000
# lr 8.000000e-01 reg 6.000000e-05 training accuracy: 0.880898 validation accuracy: 0.582000
# lr 8.000000e-01 reg 7.000000e-05 training accuracy: 0.878102 validation accuracy: 0.579000
# lr 8.000000e-01 reg 8.000000e-05 training accuracy: 0.879000 validation accuracy: 0.590000
# lr 8.000000e-01 reg 9.000000e-05 training accuracy: 0.874816 validation accuracy: 0.569000
#
# lr 9.000000e-01 reg 1.000000e-05 training accuracy: 0.895898 validation accuracy: 0.583000
# lr 9.000000e-01 reg 2.000000e-05 training accuracy: 0.898041 validation accuracy: 0.559000
# lr 9.000000e-01 reg 3.000000e-05 training accuracy: 0.898918 validation accuracy: 0.559000
# lr 9.000000e-01 reg 4.000000e-05 training accuracy: 0.893531 validation accuracy: 0.572000
# lr 9.000000e-01 reg 5.000000e-05 training accuracy: 0.887388 validation accuracy: 0.566000
# lr 9.000000e-01 reg 6.000000e-05 training accuracy: 0.883837 validation accuracy: 0.575000
# lr 9.000000e-01 reg 7.000000e-05 training accuracy: 0.888327 validation accuracy: 0.581000
# lr 9.000000e-01 reg 8.000000e-05 training accuracy: 0.885878 validation accuracy: 0.556000
# lr 9.000000e-01 reg 9.000000e-05 training accuracy: 0.884306 validation accuracy: 0.564000
#
# lr 1.000000e-01 reg 1.000000e-05 train accuracy: 0.613020, val accuracy: 0.580000
# lr 1.000000e-01 reg 2.000000e-05 train accuracy: 0.614673, val accuracy: 0.565000
# lr 1.000000e-01 reg 3.000000e-05 train accuracy: 0.612367, val accuracy: 0.576000
# lr 1.000000e-01 reg 4.000000e-05 train accuracy: 0.613857, val accuracy: 0.570000
# lr 1.000000e-01 reg 5.000000e-05 train accuracy: 0.612265, val accuracy: 0.579000
# lr 1.000000e-01 reg 6.000000e-05 train accuracy: 0.612878, val accuracy: 0.572000
# lr 1.000000e-01 reg 7.000000e-05 train accuracy: 0.611959, val accuracy: 0.571000
# lr 1.000000e-01 reg 8.000000e-05 train accuracy: 0.612571, val accuracy: 0.572000
# lr 1.000000e-01 reg 9.000000e-05 train accuracy: 0.611347, val accuracy: 0.575000
# lr 2.000000e-01 reg 1.000000e-05 train accuracy: 0.712041, val accuracy: 0.588000
# lr 2.000000e-01 reg 2.000000e-05 train accuracy: 0.709061, val accuracy: 0.600000
# lr 2.000000e-01 reg 3.000000e-05 train accuracy: 0.711367, val accuracy: 0.608000
# lr 2.000000e-01 reg 4.000000e-05 train accuracy: 0.709612, val accuracy: 0.597000
# lr 2.000000e-01 reg 5.000000e-05 train accuracy: 0.707551, val accuracy: 0.590000
# lr 2.000000e-01 reg 6.000000e-05 train accuracy: 0.709020, val accuracy: 0.599000
# lr 2.000000e-01 reg 7.000000e-05 train accuracy: 0.705367, val accuracy: 0.595000
# lr 2.000000e-01 reg 8.000000e-05 train accuracy: 0.707204, val accuracy: 0.592000
# lr 2.000000e-01 reg 9.000000e-05 train accuracy: 0.708306, val accuracy: 0.584000
# lr 3.000000e-01 reg 1.000000e-05 train accuracy: 0.768306, val accuracy: 0.579000
# lr 3.000000e-01 reg 2.000000e-05 train accuracy: 0.774143, val accuracy: 0.604000
# lr 3.000000e-01 reg 3.000000e-05 train accuracy: 0.772041, val accuracy: 0.605000
# lr 3.000000e-01 reg 4.000000e-05 train accuracy: 0.770510, val accuracy: 0.597000
# lr 3.000000e-01 reg 5.000000e-05 train accuracy: 0.767898, val accuracy: 0.585000
# lr 3.000000e-01 reg 6.000000e-05 train accuracy: 0.765469, val accuracy: 0.603000
# lr 3.000000e-01 reg 7.000000e-05 train accuracy: 0.768837, val accuracy: 0.606000
# lr 3.000000e-01 reg 8.000000e-05 train accuracy: 0.762959, val accuracy: 0.611000
# lr 3.000000e-01 reg 9.000000e-05 train accuracy: 0.766265, val accuracy: 0.583000
# lr 4.000000e-01 reg 1.000000e-05 train accuracy: 0.819347, val accuracy: 0.587000
# lr 4.000000e-01 reg 2.000000e-05 train accuracy: 0.809041, val accuracy: 0.574000
# lr 4.000000e-01 reg 3.000000e-05 train accuracy: 0.810918, val accuracy: 0.593000
# lr 4.000000e-01 reg 4.000000e-05 train accuracy: 0.808286, val accuracy: 0.593000
# lr 4.000000e-01 reg 5.000000e-05 train accuracy: 0.806612, val accuracy: 0.580000
# lr 4.000000e-01 reg 6.000000e-05 train accuracy: 0.809776, val accuracy: 0.592000
# lr 4.000000e-01 reg 7.000000e-05 train accuracy: 0.808184, val accuracy: 0.577000
# lr 4.000000e-01 reg 8.000000e-05 train accuracy: 0.800653, val accuracy: 0.594000
# lr 4.000000e-01 reg 9.000000e-05 train accuracy: 0.801347, val accuracy: 0.616000
# lr 5.000000e-01 reg 1.000000e-05 train accuracy: 0.835633, val accuracy: 0.587000
# lr 5.000000e-01 reg 2.000000e-05 train accuracy: 0.833776, val accuracy: 0.568000
# lr 5.000000e-01 reg 3.000000e-05 train accuracy: 0.835020, val accuracy: 0.572000
# lr 5.000000e-01 reg 4.000000e-05 train accuracy: 0.839959, val accuracy: 0.596000
# lr 5.000000e-01 reg 5.000000e-05 train accuracy: 0.832041, val accuracy: 0.585000
# lr 5.000000e-01 reg 6.000000e-05 train accuracy: 0.840041, val accuracy: 0.585000
# lr 5.000000e-01 reg 7.000000e-05 train accuracy: 0.832265, val accuracy: 0.574000
# lr 5.000000e-01 reg 8.000000e-05 train accuracy: 0.824082, val accuracy: 0.575000
# lr 5.000000e-01 reg 9.000000e-05 train accuracy: 0.830816, val accuracy: 0.582000
# lr 6.000000e-01 reg 1.000000e-05 train accuracy: 0.861959, val accuracy: 0.579000
# lr 6.000000e-01 reg 2.000000e-05 train accuracy: 0.860388, val accuracy: 0.563000
# lr 6.000000e-01 reg 3.000000e-05 train accuracy: 0.858633, val accuracy: 0.584000
# lr 6.000000e-01 reg 4.000000e-05 train accuracy: 0.859857, val accuracy: 0.574000
# lr 6.000000e-01 reg 5.000000e-05 train accuracy: 0.857408, val accuracy: 0.584000
# lr 6.000000e-01 reg 6.000000e-05 train accuracy: 0.854510, val accuracy: 0.586000
# lr 6.000000e-01 reg 7.000000e-05 train accuracy: 0.851633, val accuracy: 0.586000
# lr 6.000000e-01 reg 8.000000e-05 train accuracy: 0.852551, val accuracy: 0.594000
# lr 6.000000e-01 reg 9.000000e-05 train accuracy: 0.849959, val accuracy: 0.581000
# lr 7.000000e-01 reg 1.000000e-05 train accuracy: 0.868347, val accuracy: 0.572000
# lr 7.000000e-01 reg 2.000000e-05 train accuracy: 0.875327, val accuracy: 0.589000
# lr 7.000000e-01 reg 3.000000e-05 train accuracy: 0.870490, val accuracy: 0.577000
# lr 7.000000e-01 reg 4.000000e-05 train accuracy: 0.865551, val accuracy: 0.574000
# lr 7.000000e-01 reg 5.000000e-05 train accuracy: 0.872306, val accuracy: 0.582000
# lr 7.000000e-01 reg 6.000000e-05 train accuracy: 0.862184, val accuracy: 0.579000
# lr 7.000000e-01 reg 7.000000e-05 train accuracy: 0.862469, val accuracy: 0.563000
# lr 7.000000e-01 reg 8.000000e-05 train accuracy: 0.865469, val accuracy: 0.567000
# lr 7.000000e-01 reg 9.000000e-05 train accuracy: 0.864531, val accuracy: 0.574000
# lr 8.000000e-01 reg 1.000000e-05 train accuracy: 0.887612, val accuracy: 0.581000
# lr 8.000000e-01 reg 2.000000e-05 train accuracy: 0.879633, val accuracy: 0.576000
# lr 8.000000e-01 reg 3.000000e-05 train accuracy: 0.878714, val accuracy: 0.549000
# lr 8.000000e-01 reg 4.000000e-05 train accuracy: 0.884939, val accuracy: 0.561000
# lr 8.000000e-01 reg 5.000000e-05 train accuracy: 0.882347, val accuracy: 0.577000
# lr 8.000000e-01 reg 6.000000e-05 train accuracy: 0.880898, val accuracy: 0.582000
# lr 8.000000e-01 reg 7.000000e-05 train accuracy: 0.878102, val accuracy: 0.579000
# lr 8.000000e-01 reg 8.000000e-05 train accuracy: 0.879000, val accuracy: 0.590000
# lr 8.000000e-01 reg 9.000000e-05 train accuracy: 0.874816, val accuracy: 0.569000
# lr 9.000000e-01 reg 1.000000e-05 train accuracy: 0.895898, val accuracy: 0.583000
# lr 9.000000e-01 reg 2.000000e-05 train accuracy: 0.898041, val accuracy: 0.559000
# lr 9.000000e-01 reg 3.000000e-05 train accuracy: 0.898918, val accuracy: 0.559000
# lr 9.000000e-01 reg 4.000000e-05 train accuracy: 0.893531, val accuracy: 0.572000
# lr 9.000000e-01 reg 5.000000e-05 train accuracy: 0.887388, val accuracy: 0.566000
# lr 9.000000e-01 reg 6.000000e-05 train accuracy: 0.883837, val accuracy: 0.575000
# lr 9.000000e-01 reg 7.000000e-05 train accuracy: 0.888327, val accuracy: 0.581000
# lr 9.000000e-01 reg 8.000000e-05 train accuracy: 0.885878, val accuracy: 0.556000
# lr 9.000000e-01 reg 9.000000e-05 train accuracy: 0.884306, val accuracy: 0.564000
# best validation accuracy achieved during cross-validation: 0.616000

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.576
